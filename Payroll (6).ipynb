# %% [markdown]
# ## 1_ Read data using pands

# %%
import pandas as pd
data = pd.read_csv('payroll_data.csv')

# %% [markdown]
# ## 2_ show first 18 recorods

# %%
data.head(18)
# Out:
#                   Name       Job Titles Department Full or Part-Time  \
# 0     ALLISON,  PAUL W       LIEUTENANT       FIRE                 F
# 1      BRUNO,  KEVIN D         SERGEANT     POLICE                 F
# 2      COOPER,  JOHN E   LIEUTENANT-EMT       FIRE                 F
# 3     CRESPO,  VILMA I       STAFF ASST        LAW                 F
# 4     DOLAN,  ROBERT J         SERGEANT     POLICE                 F
# 5     DUBERT,  TOMASZ     PARAMEDIC I/C       FIRE                 F
# 6      EDWARDS,  TIM P       LIEUTENANT       FIRE                 F
# 7      ELKINS,  ERIC J         SERGEANT     POLICE                 F
# 8     ESTRADA,  LUIS F   POLICE OFFICER     POLICE                 F
# 9      EWING,  MARIE A        CLERK III     POLICE                 F
# 10       FINN,  SEAN P      FIREFIGHTER       FIRE                 F
# 11    FITCH,  JORDAN M        LAW CLERK        LAW                 F
# 12  FREELON,  CHERYL N   POLICE OFFICER     POLICE                 F
# ...

# %% [markdown]
# ## 3_ get the overview of my data

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32658 entries, 0 to 32657
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Name               32658 non-null  object
#  1   Job Titles         32658 non-null  object
#  2   Department         32658 non-null  object
#  3   Full or Part-Time  32658 non-null  object
#  4   Salary or Hourly   32658 non-null  object
#  5   Typical Hours      7883 non-null   float64
#  6   Annual Salary      24775 non-null  object
#  7   Hourly Rate        7883 non-null   object
# dtypes: float64(1), object(7)
# memory usage: 2.0+ MB

# %% [markdown]
# ## 4_ how many 'NaN' i have in each colum in my data

# %%
data.isnull().sum()
# Out:
# Name                     0
# Job Titles               0
# Department               0
# Full or Part-Time        0
# Salary or Hourly         0
# Typical Hours        24775
# Annual Salary         7883
# Hourly Rate          24775
# dtype: int64

# %% [markdown]
# ## 5_ output the statistics for my dataset

# %%
data.dtypes
# Out:
# Name                  object
# Job Titles            object
# Department            object
# Full or Part-Time     object
# Salary or Hourly      object
# Typical Hours        float64
# Annual Salary         object
# Hourly Rate           object
# dtype: object

# %%
data.describe()
# Out:
#        Typical Hours
# count    7883.000000
# mean       34.698719
# std         9.145553
# min        10.000000
# 25%        20.000000
# 50%        40.000000
# 75%        40.000000
# max        40.000000

# %%
data.describe(include='all')
# Out:
#                       Name      Job Titles Department Full or Part-Time  \
# count                32658           32658      32658             32658
# unique               32350            1095         36                 2
# top     HERNANDEZ,  JUAN C  POLICE OFFICER     POLICE                 F
# freq                     5            9393      12973             30676
# mean                   NaN             NaN        NaN               NaN
# std                    NaN             NaN        NaN               NaN
# min                    NaN             NaN        NaN               NaN
# 25%                    NaN             NaN        NaN               NaN
# 50%                    NaN             NaN        NaN               NaN
# 75%                    NaN             NaN        NaN               NaN
# max                    NaN             NaN        NaN               NaN
#
#        Salary or Hourly  Typical Hours Annual Salary Hourly Rate
# ...

# %%
data['Typical Hours'].describe(include='all').transpose()
# Out:
# count    7883.000000
# mean       34.698719
# std         9.145553
# min        10.000000
# 25%        20.000000
# 50%        40.000000
# 75%        40.000000
# max        40.000000
# Name: Typical Hours, dtype: float64

# %%
data.describe(include='all').transpose()
# Out:
#                     count unique                 top   freq       mean  \
# Name                32658  32350  HERNANDEZ,  JUAN C      5        NaN
# Job Titles          32658   1095      POLICE OFFICER   9393        NaN
# Department          32658     36              POLICE  12973        NaN
# Full or Part-Time   32658      2                   F  30676        NaN
# Salary or Hourly    32658      2              Salary  24775        NaN
# Typical Hours      7883.0    NaN                 NaN    NaN  34.698719
# Annual Salary       24775   1038           $90024.00   2368        NaN
# Hourly Rate          7883    167              $35.60   1404        NaN
#
#                         std   min   25%   50%   75%   max
# Name                    NaN   NaN   NaN   NaN   NaN   NaN
# Job Titles              NaN   NaN   NaN   NaN   NaN   NaN
# Department              NaN   NaN   NaN   NaN   NaN   NaN
# Full or Part-Time       NaN   NaN   NaN   NaN   NaN   NaN
# ...

# %% [markdown]
# ## 6_ what are the maximum, minimum, and average Typical Hours? (use Typical Hour) column

# %%
print('Max Typical Hours are:', data['Typical Hours'].max())
print('Min Typical Hours are:', data['Typical Hours'].min())
print('Mean/Avg Typical Hours are:', data['Typical Hours'].mean())
# Out:
# Max Typical Hours are: 40.0
# Min Typical Hours are: 10.0
# Mean/Avg Typical Hours are: 34.69871876189268

# %% [markdown]
# ## 7_ how many employees are on Salary and how many are working on Hourly basis?

# %%
data.groupby('Salary or Hourly').count()
# Out:
#                    Name  Job Titles  Department  Full or Part-Time  \
# Salary or Hourly
# Hourly             7883        7883        7883               7883
# Salary            24775       24775       24775              24775
#
#                   Typical Hours  Annual Salary  Hourly Rate
# Salary or Hourly
# Hourly                     7883              0         7883
# Salary                        0          24775            0

# %%
data['Salary or Hourly'].groupby(data['Salary or Hourly']).count()
# Out:
# Salary or Hourly
# Hourly     7883
# Salary    24775
# Name: Salary or Hourly, dtype: int64

# %% [markdown]
# ## 8_ which department has maximum number of employees?

# %%
data['Department'].value_counts().head()
# Out:
# Department
# POLICE           12973
# FIRE              4800
# STREETS & SAN     2194
# OEMC              2044
# WATER MGMNT       1878
# Name: count, dtype: int64

# %% [markdown]
# ## 9_ how many employees are on Salary and how many are on Hourly in the Police department?

# %%
data[data['Department']=='POLICE'].groupby('Salary or Hourly').count()
# Out:
#                    Name  Job Titles  Department  Full or Part-Time  \
# Salary or Hourly
# Hourly               32          32          32                 32
# Salary            12941       12941       12941              12941
#
#                   Typical Hours  Annual Salary  Hourly Rate
# Salary or Hourly
# Hourly                       32              0           32
# Salary                        0          12941            0

# %%
data[data['Department']=='POLICE'].groupby('Salary or Hourly').count()['Department']
# Out:
# Salary or Hourly
# Hourly       32
# Salary    12941
# Name: Department, dtype: int64

# %% [markdown]
# ## 10_ what are the mean, max and mi salaries?

# %%
data['Salary']=data['Annual Salary'].str.replace('$', '').astype(float)

# %%
data.head(8)
# Out:
#                Name      Job Titles Department Full or Part-Time  \
# 0  ALLISON,  PAUL W      LIEUTENANT       FIRE                 F
# 1   BRUNO,  KEVIN D        SERGEANT     POLICE                 F
# 2   COOPER,  JOHN E  LIEUTENANT-EMT       FIRE                 F
# 3  CRESPO,  VILMA I      STAFF ASST        LAW                 F
# 4  DOLAN,  ROBERT J        SERGEANT     POLICE                 F
# 5  DUBERT,  TOMASZ    PARAMEDIC I/C       FIRE                 F
# 6   EDWARDS,  TIM P      LIEUTENANT       FIRE                 F
# 7   ELKINS,  ERIC J        SERGEANT     POLICE                 F
#
#   Salary or Hourly  Typical Hours Annual Salary Hourly Rate    Salary
# 0           Salary            NaN    $107790.00         NaN  107790.0
# 1           Salary            NaN    $104628.00         NaN  104628.0
# 2           Salary            NaN    $114324.00         NaN  114324.0
# 3           Salary            NaN     $76932.00         NaN   76932.0
# ...

# %%
data.drop('Annual Salary',axis=1,inplace=True)

# %%
data.head(8)
# Out:
#                Name      Job Titles Department Full or Part-Time  \
# 0  ALLISON,  PAUL W      LIEUTENANT       FIRE                 F
# 1   BRUNO,  KEVIN D        SERGEANT     POLICE                 F
# 2   COOPER,  JOHN E  LIEUTENANT-EMT       FIRE                 F
# 3  CRESPO,  VILMA I      STAFF ASST        LAW                 F
# 4  DOLAN,  ROBERT J        SERGEANT     POLICE                 F
# 5  DUBERT,  TOMASZ    PARAMEDIC I/C       FIRE                 F
# 6   EDWARDS,  TIM P      LIEUTENANT       FIRE                 F
# 7   ELKINS,  ERIC J        SERGEANT     POLICE                 F
#
#   Salary or Hourly  Typical Hours Hourly Rate    Salary
# 0           Salary            NaN         NaN  107790.0
# 1           Salary            NaN         NaN  104628.0
# 2           Salary            NaN         NaN  114324.0
# 3           Salary            NaN         NaN   76932.0
# 4           Salary            NaN         NaN  111474.0
# ...

# %%
print('max:', data['Salary'].max())
print('min:', data['Salary'].min())
print('mean:', data['Salary'].mean())
# Out:
# max: 300000.0
# min: 0.96
# mean: 87512.78024137235

# %% [markdown]
# ## 11_ find an employee who has the maximum salary?

# %%
data[data['Salary']==data['Salary'].max()]
# Out:
#                   Name                Job Titles Department Full or Part-Time  \
# 8310  EVANS,  GINGER S  COMMISSIONER OF AVIATION   AVIATION                 F
#
#      Salary or Hourly  Typical Hours Hourly Rate    Salary
# 8310           Salary            NaN         NaN  300000.0

# %%
data.loc[data['Salary'].idxmax()]
# Out:
# Name                         EVANS,  GINGER S
# Job Titles           COMMISSIONER OF AVIATION
# Department                           AVIATION
# Full or Part-Time                           F
# Salary or Hourly                       Salary
# Typical Hours                             NaN
# Hourly Rate                               NaN
# Salary                               300000.0
# Name: 8310, dtype: object

# %% [markdown]
# ## 12_ find an employee who has the minimum salary?

# %%
data[data['Salary']==data['Salary'].min()]
# Out:
#                  Name                Job Titles      Department  \
# 15387  KOCH,  STEVEN   ADMINISTRATIVE SECRETARY  MAYOR'S OFFICE
#
#       Full or Part-Time Salary or Hourly  Typical Hours Hourly Rate  Salary
# 15387                 F           Salary            NaN         NaN    0.96

# %%
data.loc[data['Salary'].idxmin()]
# Out:
# Name                           KOCH,  STEVEN
# Job Titles           ADMINISTRATIVE SECRETARY
# Department                     MAYOR'S OFFICE
# Full or Part-Time                           F
# Salary or Hourly                       Salary
# Typical Hours                             NaN
# Hourly Rate                               NaN
# Salary                                   0.96
# Name: 15387, dtype: object

# %% [markdown]
# ## 13_ what are the max, min and mean Hourly Rate?

# %%
data['H_Rate']=data['Hourly Rate'].str.replace('$', '').astype(float)

# %%
data.head(30)
# Out:
#                   Name       Job Titles Department Full or Part-Time  \
# 0     ALLISON,  PAUL W       LIEUTENANT       FIRE                 F
# 1      BRUNO,  KEVIN D         SERGEANT     POLICE                 F
# 2      COOPER,  JOHN E   LIEUTENANT-EMT       FIRE                 F
# 3     CRESPO,  VILMA I       STAFF ASST        LAW                 F
# 4     DOLAN,  ROBERT J         SERGEANT     POLICE                 F
# 5     DUBERT,  TOMASZ     PARAMEDIC I/C       FIRE                 F
# 6      EDWARDS,  TIM P       LIEUTENANT       FIRE                 F
# 7      ELKINS,  ERIC J         SERGEANT     POLICE                 F
# 8     ESTRADA,  LUIS F   POLICE OFFICER     POLICE                 F
# 9      EWING,  MARIE A        CLERK III     POLICE                 F
# 10       FINN,  SEAN P      FIREFIGHTER       FIRE                 F
# 11    FITCH,  JORDAN M        LAW CLERK        LAW                 F
# 12  FREELON,  CHERYL N   POLICE OFFICER     POLICE                 F
# ...

# %%
print('max H_Rate :', data['H_Rate'].max())
print('min  H_Rate :', data['H_Rate'].min())
print('mean  H_Rate :', data['H_Rate'].mean())
# Out:
# max H_Rate : 96.0
# min  H_Rate : 2.65
# mean  H_Rate : 32.86819231257135

# %% [markdown]
# ## 14_ how many employees are getting max Hourly Rate?

# %%
data[data['H_Rate']==data['H_Rate'].max()].count()
# Out:
# Name                 1
# Job Titles           1
# Department           1
# Full or Part-Time    1
# Salary or Hourly     1
# Typical Hours        1
# Hourly Rate          1
# Salary               0
# H_Rate               1
# dtype: int64

# %% [markdown]
# ## 15_ how is getting max Hourly Rate?

# %%
data[data['H_Rate']==data['H_Rate'].max()]
# Out:
#                  Name    Job Titles Department Full or Part-Time  \
# 14317  JONES,  JOHN W  PSYCHIATRIST     HEALTH                 F
#
#       Salary or Hourly  Typical Hours Hourly Rate  Salary  H_Rate
# 14317           Hourly           35.0      $96.00     NaN    96.0

# %% [markdown]
# ## 16_ how many employees are earning less than the average Hourly Rate?

# %%
data['H_Rate'].mean()
# Out:
# 32.86819231257135

# %%
data[data['H_Rate'] < data['H_Rate'].mean()].count()['H_Rate']
# Out:
# 2791

# %%
data[data['H_Rate'] > data['H_Rate'].mean()].count()['H_Rate']
# Out:
# 5092

# %% [markdown]
# ## 17_ how many employees are paid hourly and the have full_time job?

# %%
data[(data['H_Rate'].notnull())&(data['Full or Part-Time']=='F')].count()['Full or Part-Time']
# Out:
# 5906

# %%
data[(data['Hourly Rate'].notnull())&(data['Full or Part-Time']=='P')].count()['Full or Part-Time']
# Out:
# 1977

# %% [markdown]
# ## 18_ find the full_time employees  who are working at hourly rate of 10.00$?

# %%
data[(data['Full or Part-Time']=='F')&(data['H_Rate']==10.00)]
# Out:
#                        Name          Job Titles       Department  \
# 1232      AYALA JR,  JESUS       STUDENT INTERN  HUMAN RESOURCES
# 4522   CERVANTES,  BIANCA A      STUDENT INTERN    BUDGET & MGMT
# 6476     DAVILA,  ROBERTO A     ALDERMANIC AIDE     CITY COUNCIL
# 16474         LEVY,  ETHAN   CLERK CITY COUNCIL     CITY COUNCIL
#
#       Full or Part-Time Salary or Hourly  Typical Hours Hourly Rate  Salary  \
# 1232                  F           Hourly           35.0      $10.00     NaN
# 4522                  F           Hourly           35.0      $10.00     NaN
# 6476                  F           Hourly           35.0      $10.00     NaN
# 16474                 F           Hourly           35.0      $10.00     NaN
#
#        H_Rate
# 1232     10.0
# 4522     10.0
# 6476     10.0
# 16474    10.0

# %% [markdown]
# ## 19_ how many unique Job are there in the data?

# %%
data['Job Titles'].nunique()
# Out:
# 1095

# %% [markdown]
# ## 20_ what was the average Salary of the employee in each department?

# %%
data.groupby('Department')['Salary'].mean()
# Out:
# Department
# ADMIN HEARNG             78912.947368
# ANIMAL CONTRL            66089.684211
# AVIATION                 76140.018777
# BOARD OF ELECTION        56051.142857
# BOARD OF ETHICS          94552.500000
# BUDGET & MGMT            93925.395349
# BUILDINGS                98864.833534
# BUSINESS AFFAIRS         80446.425000
# CITY CLERK               69762.439024
# CITY COUNCIL             63577.172069
# COMMUNITY DEVELOPMENT    88363.257143
# COPA                     98784.705882
# CULTURAL AFFAIRS         87048.909091
# DISABILITIES             82431.724138
# DoIT                     99681.029703
# FAMILY & SUPPORT         79013.588785
# FINANCE                  73276.364662
# FIRE                     97762.348662
# GENERAL SERVICES         83095.528390
# HEALTH                   85488.210938
# HUMAN RELATIONS          93778.588235
# HUMAN RESOURCES          79851.761194
# INSPECTOR GEN            84030.666667
# IPRA                     94429.285714
# ...

# %% [markdown]
# ## 21_ what are the top most common job title?

# %%
data['Job Titles'].value_counts().head()
# Out:
# Job Titles
# POLICE OFFICER                            9393
# FIREFIGHTER-EMT                           1424
# SERGEANT                                  1118
# POOL MOTOR TRUCK DRIVER                    996
# POLICE OFFICER (ASSIGNED AS DETECTIVE)     845
# Name: count, dtype: int64

# %% [markdown]
# ## 22_ how many people have the world 'officer' in their job title?

# %%
def find_string(title):
    if 'officer' in title.lower():
        return True
    else:
        return False
        sum(data['Job Titles'].apply(lambda x: find_string(x)))
